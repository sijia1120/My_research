# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
import keras
import keras.backend as K
from keras.layers import Input, Convolution2D, Activation, MaxPooling2D, Dense, BatchNormalization, Dropout
from keras.layers.core import Flatten
from keras.optimizers import SGD
from keras.models import Model
from keras.utils import np_utils
from keras.constraints import maxnorm
from keras.regularizers import l2
from keras.callbacks import LearningRateScheduler
from keras.layers import BatchNormalization

from tensorflow.keras.layers import Input, Dense, Multiply, Concatenate

# %%
# layer by layer pre-training models 

# Layer 1
input_num = Input(shape=(49,))
distorted_input1 = Dropout(.1)(input_num)
encoded1 = Dense(100, activation = 'relu')(input_num)
encoded1_bn = BatchNormalization()(encoded1)
decoded1 = Dense(49, activation = 'relu')(encoded1_bn)

autoencoder1 = Model(inputs = input_num, outputs = decoded1)
encoder1 = Model(inputs = input_num, outputs = encoded1_bn)

# Layer 2
encoded1_input = Input(shape = (100,))
distorted_input2 = Dropout(.2)(encoded1_input)
encoded2 = Dense(50, activation = 'relu')(distorted_input2)
encoded2_bn = BatchNormalization()(encoded2)
decoded2 = Dense(100, activation = 'relu')(encoded2_bn)

autoencoder2 = Model(inputs = encoded1_input, outputs = decoded2)
encoder2 = Model(inputs = encoded1_input, outputs = encoded2_bn)

# Layer 3 - which we won't end up fitting in the interest of time
encoded2_input = Input(shape = (50,))
distorted_input3 = Dropout(.3)(encoded2_input)
encoded3 = Dense(4, activation = 'relu')(distorted_input3)
encoded3_bn = BatchNormalization()(encoded3)
decoded3 = Dense(64, activation = 'relu')(encoded3_bn)

autoencoder3 = Model(inputs = encoded2_input, outputs = decoded3)
encoder3 = Model(inputs = encoded2_input, outputs = encoded3_bn)


# Deep Autoencoder ---------------------------------------------
encoded1_da = Dense(100, activation = 'sigmoid')(input_num)
encoded1_da_bn = BatchNormalization()(encoded1_da)
encoded2_da = Dense(50, activation = 'sigmoid')(encoded1_da_bn)
encoded2_da_bn = BatchNormalization()(encoded2_da)
encoded3_da = Dense(4, activation = 'sigmoid')(encoded2_da_bn)
encoded3_da_bn = BatchNormalization()(encoded3_da)
decoded3_da = Dense(50, activation = 'sigmoid')(encoded3_da_bn)
decoded2_da = Dense(100, activation = 'sigmoid')(decoded3_da)
decoded1_da = Dense(49, activation = 'sigmoid')(decoded2_da)

deep_autoencoder = Model(inputs = input_num, outputs = decoded1_da)

# Not as Deep Autoencoder
nad_encoded1_da = Dense(100, activation = 'sigmoid')(input_num)
nad_encoded1_da_bn = BatchNormalization()(nad_encoded1_da)
nad_encoded2_da = Dense(50, activation = 'sigmoid')(nad_encoded1_da_bn)
nad_encoded2_da_bn = BatchNormalization()(nad_encoded2_da)
nad_decoded2_da = Dense(100, activation = 'sigmoid')(nad_encoded2_da_bn)
nad_decoded1_da = Dense(49, activation = 'sigmoid')(nad_decoded2_da)

nad_deep_autoencoder = Model(inputs = input_num, outputs = nad_decoded1_da)

# %%
lr = 0.0001
sgd1 = keras.optimizers.Adam(learning_rate=lr)
sgd2 = keras.optimizers.Adam(learning_rate=lr)
sgd3 = keras.optimizers.Adam(learning_rate=lr)

autoencoder1.compile(loss='mean_squared_error', optimizer = sgd1)
autoencoder2.compile(loss='mean_squared_error', optimizer = sgd2)
autoencoder3.compile(loss='mean_squared_error', optimizer = sgd3)

encoder1.compile(loss='mean_squared_error', optimizer = sgd1)
encoder2.compile(loss='mean_squared_error', optimizer = sgd1)
encoder3.compile(loss='mean_squared_error', optimizer = sgd1)

deep_autoencoder.compile(loss='mean_squared_error', optimizer = sgd1)
nad_deep_autoencoder.compile(loss='mean_squared_error', optimizer = sgd1)

# %%
autoencoder1.fit(training_inputs, training_inputs,
                nb_epoch = 8, batch_size = 512,
                validation_split = 0.30,
                shuffle = True)

# %%
first_layer_code = encoder1.predict(training_inputs)
print(first_layer_code.shape)

# %%
autoencoder2.fit(first_layer_code, first_layer_code,
                nb_epoch = 8, batch_size = 512,
                validation_split = 0.25,
                shuffle = True)

# %%
# Setting up the weights of the not-as-deep autoencoder
nad_deep_autoencoder.layers[1].set_weights(autoencoder1.layers[2].get_weights()) # first dense layer
nad_deep_autoencoder.layers[2].set_weights(autoencoder1.layers[3].get_weights()) # first bn layer
nad_deep_autoencoder.layers[3].set_weights(autoencoder2.layers[2].get_weights()) # second dense layer
nad_deep_autoencoder.layers[4].set_weights(autoencoder2.layers[3].get_weights()) # second bn layer
nad_deep_autoencoder.layers[5].set_weights(autoencoder2.layers[4].get_weights()) # second decoder
nad_deep_autoencoder.layers[6].set_weights(autoencoder1.layers[4].get_weights()) # third decoder

# %% [markdown]
# ---

# %%
#merged_latent.to_pickle('merged_latent49.pkl')
merged_latent = pd.read_pickle("merged_latent49.pkl")

# merged data 1
firm_col = merged_latent.columns.tolist()[18:18+49]
latent_col = merged_latent.columns.tolist()[18+49+1:]
print(len(firm_col), len(latent_col))
# Out:
# 49 49

# %%
df_train = merged_latent[merged_latent.index < pd.Period((str(1995)+"-1"),freq='M')]
df_val = merged_latent[(merged_latent.index >= pd.Period((str(1995)+"-1"),freq='M')) & (merged_latent.index < pd.Period((str(2000)+"-1"),freq='M'))]
df_test = merged_latent[merged_latent.index >= pd.Period((str(2000)+"-1"),freq='M')]

merged_train_firm = df_train[firm_col]
merged_train_latent = df_train[latent_col]
merged_train_y = df_train['predicted_return']
print(merged_train_firm.shape, merged_train_latent.shape, merged_train_y.shape)

merged_val_firm = df_val[firm_col]
merged_val_latent = df_val[latent_col]
merged_val_y = df_val['predicted_return']
print(merged_val_firm.shape, merged_val_latent.shape, merged_val_y.shape)

merged_test_firm = df_test[firm_col]
merged_test_latent = df_test[latent_col]
merged_test_y = df_test['predicted_return']
print(merged_test_firm.shape, merged_test_latent.shape, merged_test_y.shape)
# Out:
# (88347, 49) (88347, 49) (88347,)
# (31851, 49) (31851, 49) (31851,)
# (90007, 49) (90007, 49) (90007,)

# %%
def Autoencoder():
    input_img = Input(shape=(49, ))
    encoded1 = Dense(6, activation='sigmoid')(input_img)
    decoded1 = Dense(49, activation='sigmoid')(encoded1)
    
    autoencoder = Model(inputs=input_img, outputs=decoded1)
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    autoencoder.compile(loss='mean_squared_error', optimizer=opt, metrics=[my_metric_fn])
    return autoencoder

autoencoder = Autoencoder()

# %%
def my_metric_fn(y_true, y_pred):
    num = tf.reduce_mean(tf.square(y_true - y_pred))
    den = tf.reduce_mean(tf.square(y_true))
    return 1 - num / den

def multi_input_model():
    l1_reg = 0.0
    l2_reg = 0.0
    dropout = 0.0
    lr = 0.0001
        
    # Define the hidden layers 
    input1 = Input(shape=(49,))
    x1 = Dense(6, activation='relu')(input1)
        
    # Input 2
    input2 = Input(shape=(49,))
    x2 = Dense(32, activation='relu',)(input2)
    x2 = Dense(16, activation='relu',)(x2)
    x2 = Dense(6, activation='relu',)(x2)
        
    merged = Multiply()([x1, x2])
    output = Dense(1, activation='linear')(merged)
 
    # Create the model 
    model = Model(inputs=[input1, input2], outputs=output)
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(loss='mean_squared_error', optimizer=opt,metrics=[my_metric_fn])
    return model

# %%
import random 

seed_list = [458, 165, 530, 564, 590, 560, 829, 170, 376, 176]
yhat_df = pd.DataFrame()

for random_seed in seed_list:
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
 
    model = multi_input_model()
    model.layers[4].set_weights(autoencoder1.layers[1].get_weights())
    model.layers[4].trainable = False
    model.fit([merged_train_latent, merged_train_firm], merged_train_y,
                   epochs=50,
                   validation_data=([merged_val_latent, merged_val_firm], merged_val_y),
                   callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=1)])
    print(model.evaluate([merged_test_latent, merged_test_firm], merged_test_y))
    y_hat = model.predict([merged_test_latent, merged_test_firm]).reshape(-1)
    yhat_df[random_seed] = y_hat
    print()

# Print out Predictive R^2
y_predict = yhat_df.mean(axis=1).values.reshape(-1)
y_real = merged_test_y

a = np.mean(np.square(y_predict -  y_real))
b = np.mean(np.square(y_real))
print(1-a/b)
# Out:
# Epoch 1/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0125 - my_metric_fn: -0.0425 - val_loss: 0.0146 - val_my_metric_fn: 0.0039
# Epoch 2/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0010 - val_loss: 0.0146 - val_my_metric_fn: 0.0043
# Epoch 3/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0013 - val_loss: 0.0146 - val_my_metric_fn: 0.0042
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0048
# [0.015681525692343712, 0.004816832952201366]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0140 - my_metric_fn: -0.1929 - val_loss: 0.0147 - val_my_metric_fn: -0.0065
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0022 - val_loss: 0.0146 - val_my_metric_fn: 0.0031
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 9.9555e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0038
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0020 - val_loss: 0.0146 - val_my_metric_fn: 0.0036
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0050
# [0.015681354328989983, 0.004970814101397991]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0227 - my_metric_fn: -1.0709 - val_loss: 0.0147 - val_my_metric_fn: -0.0154
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0066 - val_loss: 0.0145 - val_my_metric_fn: 0.0040
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 6.8570e-04 - val_loss: 0.0145 - val_my_metric_fn: 0.0055
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0050 - val_loss: 0.0144 - val_my_metric_fn: 0.0126
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0118 - my_metric_fn: 0.0276 - val_loss: 0.0139 - val_my_metric_fn: 0.0382
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0112 - my_metric_fn: 0.0725 - val_loss: 0.0137 - val_my_metric_fn: 0.0311
# Epoch 7/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0109 - my_metric_fn: 0.0919 - val_loss: 0.0138 - val_my_metric_fn: 0.0169
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0134 - my_metric_fn: 0.0715
# [0.013372362591326237, 0.07151620835065842]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0152 - my_metric_fn: -0.2991 - val_loss: 0.0148 - val_my_metric_fn: -0.0225
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0100 - val_loss: 0.0145 - val_my_metric_fn: 0.0032
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0140 - val_loss: 0.0141 - val_my_metric_fn: 0.0262
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0568 - val_loss: 0.0137 - val_my_metric_fn: 0.0266
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0109 - my_metric_fn: 0.0914 - val_loss: 0.0138 - val_my_metric_fn: 0.0028
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0595
# [0.013467296026647091, 0.0595315545797348]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0177 - my_metric_fn: -0.5789 - val_loss: 0.0151 - val_my_metric_fn: -0.0494
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0123 - my_metric_fn: -0.0201 - val_loss: 0.0146 - val_my_metric_fn: -0.0027
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: -0.0010 - val_loss: 0.0146 - val_my_metric_fn: 0.0026
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0023 - val_loss: 0.0146 - val_my_metric_fn: 0.0036
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0050 - val_loss: 0.0146 - val_my_metric_fn: 0.0026
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0080 - val_loss: 0.0145 - val_my_metric_fn: 0.0051
# Epoch 7/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0117 - my_metric_fn: 0.0322 - val_loss: 0.0138 - val_my_metric_fn: 0.0341
# Epoch 8/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0109 - my_metric_fn: 0.0917 - val_loss: 0.0137 - val_my_metric_fn: 0.0168
# Epoch 9/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0106 - my_metric_fn: 0.1151 - val_loss: 0.0138 - val_my_metric_fn: 0.0053
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0646
# [0.013502286747097969, 0.06455272436141968]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0134 - my_metric_fn: -0.1281 - val_loss: 0.0146 - val_my_metric_fn: 0.0027
# Epoch 2/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0031 - val_loss: 0.0144 - val_my_metric_fn: 0.0139
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0181 - val_loss: 0.0140 - val_my_metric_fn: 0.0334
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0116 - my_metric_fn: 0.0440 - val_loss: 0.0138 - val_my_metric_fn: 0.0432
# Epoch 5/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0677 - val_loss: 0.0137 - val_my_metric_fn: 0.0342
# Epoch 6/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0111 - my_metric_fn: 0.0812 - val_loss: 0.0138 - val_my_metric_fn: 0.0167
# 2813/2813 [==============================] - 7s 2ms/step - loss: 0.0141 - my_metric_fn: 0.0552
# [0.014071732759475708, 0.055243004113435745]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0137 - my_metric_fn: -0.1659 - val_loss: 0.0147 - val_my_metric_fn: -0.0075
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: -0.0020 - val_loss: 0.0146 - val_my_metric_fn: 0.0018
# Epoch 3/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0014 - val_loss: 0.0146 - val_my_metric_fn: 0.0028
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0030 - val_loss: 0.0146 - val_my_metric_fn: 0.0017
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0035
# [0.01568356156349182, 0.0035485841799527407]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0178 - my_metric_fn: -0.5866 - val_loss: 0.0146 - val_my_metric_fn: -0.0074
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 9.2326e-05 - val_loss: 0.0143 - val_my_metric_fn: 0.0151
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0220 - val_loss: 0.0140 - val_my_metric_fn: 0.0348
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0112 - my_metric_fn: 0.0791 - val_loss: 0.0136 - val_my_metric_fn: 0.0219
# Epoch 5/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0105 - my_metric_fn: 0.1251 - val_loss: 0.0137 - val_my_metric_fn: 0.0107
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0609
# [0.013495287857949734, 0.060852549970149994]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0131 - my_metric_fn: -0.0930 - val_loss: 0.0146 - val_my_metric_fn: -0.0017
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: -9.0620e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0040
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0034 - val_loss: 0.0145 - val_my_metric_fn: 0.0061
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0061 - val_loss: 0.0145 - val_my_metric_fn: 0.0086
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0126 - val_loss: 0.0143 - val_my_metric_fn: 0.0186
# Epoch 6/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0118 - my_metric_fn: 0.0287 - val_loss: 0.0139 - val_my_metric_fn: 0.0362
# Epoch 7/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0115 - my_metric_fn: 0.0540 - val_loss: 0.0138 - val_my_metric_fn: 0.0372
# Epoch 8/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0112 - my_metric_fn: 0.0715 - val_loss: 0.0138 - val_my_metric_fn: 0.0269
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0142 - my_metric_fn: 0.0517
# [0.014215349219739437, 0.05172201618552208]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0165 - my_metric_fn: -0.4260 - val_loss: 0.0149 - val_my_metric_fn: -0.0314
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0092 - val_loss: 0.0146 - val_my_metric_fn: 1.5024e-05
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 2.6714e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0032
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0028 - val_loss: 0.0146 - val_my_metric_fn: 0.0020
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0039
# [0.015670256689190865, 0.00388901773840189]
# 2813/2813 [==============================] - 5s 2ms/step
#
# 0.1384320517305404

# %%
import random 

seed_list = [458, 165, 530, 564, 590, 560, 829, 170, 376, 176]
yhat_df = pd.DataFrame()

for random_seed in seed_list:
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    
    autoencoder = Autoencoder()
    autoencoder.fit(merged_train_latent, merged_train_latent,
                epochs = 20, batch_size = 216,
                validation_data = (merged_val_latent, merged_val_latent),
                 callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=1)])
 
    model = multi_input_model()
    model.layers[4].set_weights(autoencoder.layers[1].get_weights())
    model.layers[4].trainable = False
    model.fit([merged_train_latent, merged_train_firm], merged_train_y,
                   epochs=50,
                   validation_data=([merged_val_latent, merged_val_firm], merged_val_y),
                   callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=1)])
    print(model.evaluate([merged_test_latent, merged_test_firm], merged_test_y))
    y_hat = model.predict([merged_test_latent, merged_test_firm]).reshape(-1)
    yhat_df[random_seed] = y_hat
    print()

# Print out Predictive R^2
y_predict = yhat_df.mean(axis=1).values.reshape(-1)
y_real = merged_test_y

a = np.mean(np.square(y_predict -  y_real))
b = np.mean(np.square(y_real))
print(1-a/b)
# Out:
# Epoch 1/20
# 410/410 [==============================] - 2s 3ms/step - loss: 0.2408 - my_metric_fn: -377.7255 - val_loss: 0.2217 - val_my_metric_fn: -475.6530
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.2037 - my_metric_fn: -318.0138 - val_loss: 0.1864 - val_my_metric_fn: -399.7114
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1700 - my_metric_fn: -265.5910 - val_loss: 0.1548 - val_my_metric_fn: -331.3271
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1401 - my_metric_fn: -219.0837 - val_loss: 0.1272 - val_my_metric_fn: -271.7142
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1143 - my_metric_fn: -177.8759 - val_loss: 0.1037 - val_my_metric_fn: -221.1305
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0926 - my_metric_fn: -144.0566 - val_loss: 0.0843 - val_my_metric_fn: -179.0626
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0748 - my_metric_fn: -116.3494 - val_loss: 0.0683 - val_my_metric_fn: -144.5743
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0603 - my_metric_fn: -93.3406 - val_loss: 0.0553 - val_my_metric_fn: -116.5812
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0485 - my_metric_fn: -75.1538 - val_loss: 0.0448 - val_my_metric_fn: -93.9983
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0391 - my_metric_fn: -60.1389 - val_loss: 0.0364 - val_my_metric_fn: -75.8443
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0316 - my_metric_fn: -48.4743 - val_loss: 0.0296 - val_my_metric_fn: -61.2745
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0256 - my_metric_fn: -38.9239 - val_loss: 0.0242 - val_my_metric_fn: -49.5800
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0207 - my_metric_fn: -31.3485 - val_loss: 0.0198 - val_my_metric_fn: -40.1866
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0169 - my_metric_fn: -25.3989 - val_loss: 0.0163 - val_my_metric_fn: -32.6306
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0138 - my_metric_fn: -20.5260 - val_loss: 0.0134 - val_my_metric_fn: -26.5398
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0113 - my_metric_fn: -16.6798 - val_loss: 0.0111 - val_my_metric_fn: -21.6196
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0093 - my_metric_fn: -13.5481 - val_loss: 0.0092 - val_my_metric_fn: -17.6389
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0077 - my_metric_fn: -11.0372 - val_loss: 0.0077 - val_my_metric_fn: -14.4110
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0064 - my_metric_fn: -8.9622 - val_loss: 0.0065 - val_my_metric_fn: -11.7885
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0053 - my_metric_fn: -7.2946 - val_loss: 0.0055 - val_my_metric_fn: -9.6542
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0141 - my_metric_fn: -0.2014 - val_loss: 0.0147 - val_my_metric_fn: -0.0099
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0032 - val_loss: 0.0145 - val_my_metric_fn: 0.0033
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0053 - val_loss: 0.0144 - val_my_metric_fn: 0.0130
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0118 - my_metric_fn: 0.0281 - val_loss: 0.0139 - val_my_metric_fn: 0.0365
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0114 - my_metric_fn: 0.0605 - val_loss: 0.0137 - val_my_metric_fn: 0.0367
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0111 - my_metric_fn: 0.0780 - val_loss: 0.0137 - val_my_metric_fn: 0.0268
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0140 - my_metric_fn: 0.0615
# [0.01402537152171135, 0.061518050730228424]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.2324 - my_metric_fn: -361.9787 - val_loss: 0.2132 - val_my_metric_fn: -457.4204
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1953 - my_metric_fn: -304.4875 - val_loss: 0.1780 - val_my_metric_fn: -381.5613
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1618 - my_metric_fn: -252.5750 - val_loss: 0.1468 - val_my_metric_fn: -314.1787
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1325 - my_metric_fn: -206.6999 - val_loss: 0.1200 - val_my_metric_fn: -256.2249
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1075 - my_metric_fn: -167.5814 - val_loss: 0.0975 - val_my_metric_fn: -207.5989
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0868 - my_metric_fn: -134.7942 - val_loss: 0.0789 - val_my_metric_fn: -167.5282
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0699 - my_metric_fn: -108.0650 - val_loss: 0.0638 - val_my_metric_fn: -134.9247
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0562 - my_metric_fn: -86.8853 - val_loss: 0.0516 - val_my_metric_fn: -108.6108
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0452 - my_metric_fn: -69.5932 - val_loss: 0.0418 - val_my_metric_fn: -87.4771
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0364 - my_metric_fn: -55.9400 - val_loss: 0.0339 - val_my_metric_fn: -70.5427
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0294 - my_metric_fn: -45.0351 - val_loss: 0.0276 - val_my_metric_fn: -56.9783
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0238 - my_metric_fn: -36.3879 - val_loss: 0.0226 - val_my_metric_fn: -46.1074
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0193 - my_metric_fn: -29.1907 - val_loss: 0.0185 - val_my_metric_fn: -37.3802
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0157 - my_metric_fn: -23.6279 - val_loss: 0.0152 - val_my_metric_fn: -30.3607
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0129 - my_metric_fn: -19.0918 - val_loss: 0.0125 - val_my_metric_fn: -24.7032
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0106 - my_metric_fn: -15.5473 - val_loss: 0.0104 - val_my_metric_fn: -20.1336
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0087 - my_metric_fn: -12.6211 - val_loss: 0.0087 - val_my_metric_fn: -16.4346
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0072 - my_metric_fn: -10.2996 - val_loss: 0.0072 - val_my_metric_fn: -13.4330
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0060 - my_metric_fn: -8.3808 - val_loss: 0.0061 - val_my_metric_fn: -10.9934
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0050 - my_metric_fn: -6.8277 - val_loss: 0.0051 - val_my_metric_fn: -9.0060
# Epoch 1/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0166 - my_metric_fn: -0.4578 - val_loss: 0.0150 - val_my_metric_fn: -0.0388
# Epoch 2/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0122 - my_metric_fn: -0.0095 - val_loss: 0.0146 - val_my_metric_fn: 0.0048
# Epoch 3/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0038 - val_loss: 0.0145 - val_my_metric_fn: 0.0102
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0169 - val_loss: 0.0141 - val_my_metric_fn: 0.0281
# Epoch 5/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0116 - my_metric_fn: 0.0462 - val_loss: 0.0138 - val_my_metric_fn: 0.0384
# Epoch 6/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0112 - my_metric_fn: 0.0706 - val_loss: 0.0138 - val_my_metric_fn: 0.0253
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0141 - my_metric_fn: 0.0629
# [0.014079166576266289, 0.06293687224388123]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 3ms/step - loss: 0.2372 - my_metric_fn: -369.4849 - val_loss: 0.2182 - val_my_metric_fn: -468.0688
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.2003 - my_metric_fn: -313.4544 - val_loss: 0.1831 - val_my_metric_fn: -392.5227
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1668 - my_metric_fn: -259.2080 - val_loss: 0.1517 - val_my_metric_fn: -324.7347
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1371 - my_metric_fn: -213.4097 - val_loss: 0.1244 - val_my_metric_fn: -265.8521
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1117 - my_metric_fn: -173.8555 - val_loss: 0.1013 - val_my_metric_fn: -216.0561
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0904 - my_metric_fn: -140.2801 - val_loss: 0.0822 - val_my_metric_fn: -174.7645
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0729 - my_metric_fn: -113.3734 - val_loss: 0.0666 - val_my_metric_fn: -140.9997
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0587 - my_metric_fn: -90.7842 - val_loss: 0.0539 - val_my_metric_fn: -113.6459
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0473 - my_metric_fn: -72.9046 - val_loss: 0.0437 - val_my_metric_fn: -91.6093
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0381 - my_metric_fn: -58.5414 - val_loss: 0.0355 - val_my_metric_fn: -73.9140
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0308 - my_metric_fn: -47.1717 - val_loss: 0.0289 - val_my_metric_fn: -59.7214
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0249 - my_metric_fn: -38.1204 - val_loss: 0.0236 - val_my_metric_fn: -48.3341
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0202 - my_metric_fn: -30.6522 - val_loss: 0.0193 - val_my_metric_fn: -39.1885
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0165 - my_metric_fn: -24.7367 - val_loss: 0.0159 - val_my_metric_fn: -31.8307
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0134 - my_metric_fn: -19.9841 - val_loss: 0.0131 - val_my_metric_fn: -25.8988
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0110 - my_metric_fn: -16.2084 - val_loss: 0.0108 - val_my_metric_fn: -21.1068
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0091 - my_metric_fn: -13.1844 - val_loss: 0.0090 - val_my_metric_fn: -17.2275
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0075 - my_metric_fn: -10.7233 - val_loss: 0.0075 - val_my_metric_fn: -14.0810
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0062 - my_metric_fn: -8.7586 - val_loss: 0.0063 - val_my_metric_fn: -11.5226
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0052 - my_metric_fn: -7.1301 - val_loss: 0.0053 - val_my_metric_fn: -9.4392
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0127 - my_metric_fn: -0.0572 - val_loss: 0.0143 - val_my_metric_fn: 0.0182
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0169 - val_loss: 0.0140 - val_my_metric_fn: 0.0369
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0116 - my_metric_fn: 0.0438 - val_loss: 0.0137 - val_my_metric_fn: 0.0460
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0659 - val_loss: 0.0137 - val_my_metric_fn: 0.0375
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0111 - my_metric_fn: 0.0821 - val_loss: 0.0138 - val_my_metric_fn: 0.0240
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0140 - my_metric_fn: 0.0594
# [0.01403113640844822, 0.059415146708488464]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.2315 - my_metric_fn: -360.9731 - val_loss: 0.2122 - val_my_metric_fn: -455.5268
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1947 - my_metric_fn: -304.2520 - val_loss: 0.1773 - val_my_metric_fn: -380.1446
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1614 - my_metric_fn: -251.5027 - val_loss: 0.1463 - val_my_metric_fn: -313.2057
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1323 - my_metric_fn: -206.1138 - val_loss: 0.1196 - val_my_metric_fn: -255.6005
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1075 - my_metric_fn: -166.8392 - val_loss: 0.0972 - val_my_metric_fn: -207.2167
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0869 - my_metric_fn: -134.8721 - val_loss: 0.0787 - val_my_metric_fn: -167.2965
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0700 - my_metric_fn: -108.7868 - val_loss: 0.0636 - val_my_metric_fn: -134.7764
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0563 - my_metric_fn: -87.4033 - val_loss: 0.0515 - val_my_metric_fn: -108.5044
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0453 - my_metric_fn: -69.8506 - val_loss: 0.0417 - val_my_metric_fn: -87.3877
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0365 - my_metric_fn: -56.2056 - val_loss: 0.0338 - val_my_metric_fn: -70.4577
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0295 - my_metric_fn: -45.1973 - val_loss: 0.0275 - val_my_metric_fn: -56.8927
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0239 - my_metric_fn: -36.2940 - val_loss: 0.0225 - val_my_metric_fn: -46.0202
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0194 - my_metric_fn: -29.3974 - val_loss: 0.0184 - val_my_metric_fn: -37.2933
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0158 - my_metric_fn: -23.6976 - val_loss: 0.0151 - val_my_metric_fn: -30.2763
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0129 - my_metric_fn: -19.2499 - val_loss: 0.0125 - val_my_metric_fn: -24.6232
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0106 - my_metric_fn: -15.5494 - val_loss: 0.0103 - val_my_metric_fn: -20.0573
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0087 - my_metric_fn: -12.6173 - val_loss: 0.0086 - val_my_metric_fn: -16.3621
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0072 - my_metric_fn: -10.2960 - val_loss: 0.0072 - val_my_metric_fn: -13.3665
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0060 - my_metric_fn: -8.3695 - val_loss: 0.0060 - val_my_metric_fn: -10.9321
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0050 - my_metric_fn: -6.8314 - val_loss: 0.0051 - val_my_metric_fn: -8.9503
# Epoch 1/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0133 - my_metric_fn: -0.1142 - val_loss: 0.0145 - val_my_metric_fn: 0.0014
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0058 - val_loss: 0.0142 - val_my_metric_fn: 0.0238
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0669 - val_loss: 0.0136 - val_my_metric_fn: 0.0307
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0106 - my_metric_fn: 0.1204 - val_loss: 0.0139 - val_my_metric_fn: -0.0050
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0561
# [0.013519848696887493, 0.056140072643756866]
# 2813/2813 [==============================] - 7s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.2268 - my_metric_fn: -354.3300 - val_loss: 0.2081 - val_my_metric_fn: -446.4465
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1907 - my_metric_fn: -297.3618 - val_loss: 0.1741 - val_my_metric_fn: -373.1098
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1584 - my_metric_fn: -246.6116 - val_loss: 0.1440 - val_my_metric_fn: -308.1270
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1301 - my_metric_fn: -203.8826 - val_loss: 0.1180 - val_my_metric_fn: -252.0502
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1059 - my_metric_fn: -164.1261 - val_loss: 0.0961 - val_my_metric_fn: -204.8013
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0858 - my_metric_fn: -133.3758 - val_loss: 0.0780 - val_my_metric_fn: -165.6928
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0692 - my_metric_fn: -107.2557 - val_loss: 0.0632 - val_my_metric_fn: -133.7318
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0558 - my_metric_fn: -86.4348 - val_loss: 0.0512 - val_my_metric_fn: -107.8338
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0449 - my_metric_fn: -69.4765 - val_loss: 0.0415 - val_my_metric_fn: -86.9643
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0362 - my_metric_fn: -55.7764 - val_loss: 0.0337 - val_my_metric_fn: -70.1968
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0293 - my_metric_fn: -44.8011 - val_loss: 0.0275 - val_my_metric_fn: -56.7379
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0237 - my_metric_fn: -36.0836 - val_loss: 0.0225 - val_my_metric_fn: -45.9346
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0193 - my_metric_fn: -29.1814 - val_loss: 0.0184 - val_my_metric_fn: -37.2536
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0157 - my_metric_fn: -23.5327 - val_loss: 0.0151 - val_my_metric_fn: -30.2643
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0128 - my_metric_fn: -19.0904 - val_loss: 0.0125 - val_my_metric_fn: -24.6284
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0105 - my_metric_fn: -15.4352 - val_loss: 0.0104 - val_my_metric_fn: -20.0745
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0087 - my_metric_fn: -12.5742 - val_loss: 0.0086 - val_my_metric_fn: -16.3873
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0072 - my_metric_fn: -10.2012 - val_loss: 0.0072 - val_my_metric_fn: -13.3937
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0060 - my_metric_fn: -8.3371 - val_loss: 0.0061 - val_my_metric_fn: -10.9592
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0050 - my_metric_fn: -6.7992 - val_loss: 0.0051 - val_my_metric_fn: -8.9783
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0137 - my_metric_fn: -0.1575 - val_loss: 0.0146 - val_my_metric_fn: 0.0036
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 3.1006e-05 - val_loss: 0.0146 - val_my_metric_fn: 0.0051
# Epoch 3/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0035 - val_loss: 0.0145 - val_my_metric_fn: 0.0112
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0242 - val_loss: 0.0137 - val_my_metric_fn: 0.0486
# Epoch 5/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0109 - my_metric_fn: 0.0945 - val_loss: 0.0138 - val_my_metric_fn: 0.0051
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0741
# [0.013462694361805916, 0.07409054785966873]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.2412 - my_metric_fn: -376.8371 - val_loss: 0.2221 - val_my_metric_fn: -476.5218
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.2041 - my_metric_fn: -318.6726 - val_loss: 0.1867 - val_my_metric_fn: -400.3784
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1703 - my_metric_fn: -265.8595 - val_loss: 0.1549 - val_my_metric_fn: -331.7494
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1402 - my_metric_fn: -219.0932 - val_loss: 0.1272 - val_my_metric_fn: -271.9277
# Epoch 5/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.1144 - my_metric_fn: -178.3483 - val_loss: 0.1037 - val_my_metric_fn: -221.1943
# Epoch 6/20
# 410/410 [==============================] - 1s 4ms/step - loss: 0.0927 - my_metric_fn: -143.8784 - val_loss: 0.0842 - val_my_metric_fn: -179.0291
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0748 - my_metric_fn: -116.3605 - val_loss: 0.0682 - val_my_metric_fn: -144.4917
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0602 - my_metric_fn: -93.5966 - val_loss: 0.0552 - val_my_metric_fn: -116.4780
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0485 - my_metric_fn: -74.8854 - val_loss: 0.0447 - val_my_metric_fn: -93.8971
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0391 - my_metric_fn: -60.1302 - val_loss: 0.0363 - val_my_metric_fn: -75.7556
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0315 - my_metric_fn: -48.2385 - val_loss: 0.0296 - val_my_metric_fn: -61.2004
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0255 - my_metric_fn: -38.9047 - val_loss: 0.0241 - val_my_metric_fn: -49.5226
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0207 - my_metric_fn: -31.4337 - val_loss: 0.0198 - val_my_metric_fn: -40.1440
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0169 - my_metric_fn: -25.3250 - val_loss: 0.0162 - val_my_metric_fn: -32.5998
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0138 - my_metric_fn: -20.6095 - val_loss: 0.0134 - val_my_metric_fn: -26.5179
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0113 - my_metric_fn: -16.6250 - val_loss: 0.0111 - val_my_metric_fn: -21.6084
# Epoch 17/20
# 410/410 [==============================] - 1s 4ms/step - loss: 0.0093 - my_metric_fn: -13.4925 - val_loss: 0.0092 - val_my_metric_fn: -17.6352
# Epoch 18/20
# 410/410 [==============================] - 1s 4ms/step - loss: 0.0077 - my_metric_fn: -10.9685 - val_loss: 0.0077 - val_my_metric_fn: -14.4127
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.0064 - my_metric_fn: -8.9586 - val_loss: 0.0065 - val_my_metric_fn: -11.7942
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.0053 - my_metric_fn: -7.3136 - val_loss: 0.0054 - val_my_metric_fn: -9.6626
# Epoch 1/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0136 - my_metric_fn: -0.1560 - val_loss: 0.0147 - val_my_metric_fn: -0.0117
# Epoch 2/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0122 - my_metric_fn: -0.0050 - val_loss: 0.0146 - val_my_metric_fn: 0.0025
# Epoch 3/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0048 - val_loss: 0.0145 - val_my_metric_fn: 0.0073
# Epoch 4/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0118 - my_metric_fn: 0.0217 - val_loss: 0.0140 - val_my_metric_fn: 0.0220
# Epoch 5/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0111 - my_metric_fn: 0.0742 - val_loss: 0.0139 - val_my_metric_fn: 0.0022
# Epoch 6/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0107 - my_metric_fn: 0.1068 - val_loss: 0.0140 - val_my_metric_fn: -0.0091
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0136 - my_metric_fn: 0.0547
# [0.013626497238874435, 0.05474544316530228]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 3ms/step - loss: 0.2442 - my_metric_fn: -379.5978 - val_loss: 0.2247 - val_my_metric_fn: -482.3583
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.2069 - my_metric_fn: -322.0428 - val_loss: 0.1891 - val_my_metric_fn: -405.7001
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1728 - my_metric_fn: -270.2353 - val_loss: 0.1571 - val_my_metric_fn: -336.6124
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.1426 - my_metric_fn: -221.6473 - val_loss: 0.1291 - val_my_metric_fn: -276.2031
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1164 - my_metric_fn: -180.7822 - val_loss: 0.1053 - val_my_metric_fn: -224.8384
# Epoch 6/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.0944 - my_metric_fn: -146.6658 - val_loss: 0.0855 - val_my_metric_fn: -182.0678
# Epoch 7/20
# 410/410 [==============================] - 1s 4ms/step - loss: 0.0762 - my_metric_fn: -118.0152 - val_loss: 0.0693 - val_my_metric_fn: -146.9796
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0614 - my_metric_fn: -95.1278 - val_loss: 0.0561 - val_my_metric_fn: -118.4849
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0495 - my_metric_fn: -76.6624 - val_loss: 0.0455 - val_my_metric_fn: -95.4982
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0399 - my_metric_fn: -61.3430 - val_loss: 0.0369 - val_my_metric_fn: -77.0218
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0322 - my_metric_fn: -49.3800 - val_loss: 0.0300 - val_my_metric_fn: -62.1948
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0261 - my_metric_fn: -39.7582 - val_loss: 0.0245 - val_my_metric_fn: -50.2990
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0211 - my_metric_fn: -32.0865 - val_loss: 0.0200 - val_my_metric_fn: -40.7473
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0172 - my_metric_fn: -25.8601 - val_loss: 0.0164 - val_my_metric_fn: -33.0665
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0140 - my_metric_fn: -21.0260 - val_loss: 0.0135 - val_my_metric_fn: -26.8799
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0115 - my_metric_fn: -17.0239 - val_loss: 0.0112 - val_my_metric_fn: -21.8855
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.0095 - my_metric_fn: -13.7780 - val_loss: 0.0093 - val_my_metric_fn: -17.8465
# Epoch 18/20
# 410/410 [==============================] - 1s 4ms/step - loss: 0.0078 - my_metric_fn: -11.2593 - val_loss: 0.0078 - val_my_metric_fn: -14.5729
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0065 - my_metric_fn: -9.1599 - val_loss: 0.0065 - val_my_metric_fn: -11.9138
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0054 - my_metric_fn: -7.4342 - val_loss: 0.0055 - val_my_metric_fn: -9.7502
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0187 - my_metric_fn: -0.6750 - val_loss: 0.0149 - val_my_metric_fn: -0.0373
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: -0.0022 - val_loss: 0.0141 - val_my_metric_fn: 0.0185
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0573 - val_loss: 0.0138 - val_my_metric_fn: 0.0279
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0108 - my_metric_fn: 0.0946 - val_loss: 0.0138 - val_my_metric_fn: 0.0122
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0135 - my_metric_fn: 0.0660
# [0.013521863147616386, 0.06598658114671707]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 0.2314 - my_metric_fn: -361.3262 - val_loss: 0.2124 - val_my_metric_fn: -455.8534
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1947 - my_metric_fn: -303.7043 - val_loss: 0.1776 - val_my_metric_fn: -380.6937
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1615 - my_metric_fn: -251.0712 - val_loss: 0.1466 - val_my_metric_fn: -313.9586
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1324 - my_metric_fn: -206.1236 - val_loss: 0.1200 - val_my_metric_fn: -256.4629
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1077 - my_metric_fn: -167.6806 - val_loss: 0.0976 - val_my_metric_fn: -208.1050
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0871 - my_metric_fn: -135.1277 - val_loss: 0.0791 - val_my_metric_fn: -168.1493
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0702 - my_metric_fn: -108.5294 - val_loss: 0.0640 - val_my_metric_fn: -135.5553
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0565 - my_metric_fn: -87.2999 - val_loss: 0.0518 - val_my_metric_fn: -109.1942
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0455 - my_metric_fn: -70.0298 - val_loss: 0.0420 - val_my_metric_fn: -87.9862
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0366 - my_metric_fn: -56.5323 - val_loss: 0.0341 - val_my_metric_fn: -70.9674
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0296 - my_metric_fn: -45.3854 - val_loss: 0.0277 - val_my_metric_fn: -57.3237
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0239 - my_metric_fn: -36.4997 - val_loss: 0.0226 - val_my_metric_fn: -46.3831
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0194 - my_metric_fn: -29.4049 - val_loss: 0.0185 - val_my_metric_fn: -37.5987
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0158 - my_metric_fn: -23.7867 - val_loss: 0.0152 - val_my_metric_fn: -30.5335
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0129 - my_metric_fn: -19.2586 - val_loss: 0.0126 - val_my_metric_fn: -24.8380
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0106 - my_metric_fn: -15.6333 - val_loss: 0.0104 - val_my_metric_fn: -20.2390
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0087 - my_metric_fn: -12.6769 - val_loss: 0.0087 - val_my_metric_fn: -16.5170
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0072 - my_metric_fn: -10.3020 - val_loss: 0.0072 - val_my_metric_fn: -13.4987
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0060 - my_metric_fn: -8.4021 - val_loss: 0.0061 - val_my_metric_fn: -11.0462
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0050 - my_metric_fn: -6.8416 - val_loss: 0.0051 - val_my_metric_fn: -9.0488
# Epoch 1/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0141 - my_metric_fn: -0.1985 - val_loss: 0.0146 - val_my_metric_fn: -0.0040
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0012 - val_loss: 0.0145 - val_my_metric_fn: 0.0070
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0105 - val_loss: 0.0142 - val_my_metric_fn: 0.0245
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0117 - my_metric_fn: 0.0377 - val_loss: 0.0138 - val_my_metric_fn: 0.0465
# Epoch 5/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0113 - my_metric_fn: 0.0645 - val_loss: 0.0137 - val_my_metric_fn: 0.0438
# Epoch 6/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0111 - my_metric_fn: 0.0815 - val_loss: 0.0138 - val_my_metric_fn: 0.0282
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0140 - my_metric_fn: 0.0631
# [0.013957790099084377, 0.06310495734214783]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 3ms/step - loss: 0.2231 - my_metric_fn: -348.3212 - val_loss: 0.2043 - val_my_metric_fn: -438.3093
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1869 - my_metric_fn: -291.0614 - val_loss: 0.1701 - val_my_metric_fn: -364.6777
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1546 - my_metric_fn: -241.1662 - val_loss: 0.1401 - val_my_metric_fn: -299.7751
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1264 - my_metric_fn: -196.7190 - val_loss: 0.1143 - val_my_metric_fn: -244.2092
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1026 - my_metric_fn: -159.0906 - val_loss: 0.0928 - val_my_metric_fn: -197.7342
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0828 - my_metric_fn: -128.1853 - val_loss: 0.0751 - val_my_metric_fn: -159.5224
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0667 - my_metric_fn: -103.2636 - val_loss: 0.0607 - val_my_metric_fn: -128.4685
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0536 - my_metric_fn: -82.8324 - val_loss: 0.0491 - val_my_metric_fn: -103.4211
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0432 - my_metric_fn: -66.4548 - val_loss: 0.0398 - val_my_metric_fn: -83.3115
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0348 - my_metric_fn: -53.4056 - val_loss: 0.0323 - val_my_metric_fn: -67.1960
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0281 - my_metric_fn: -42.9687 - val_loss: 0.0263 - val_my_metric_fn: -54.2864
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0228 - my_metric_fn: -34.6074 - val_loss: 0.0215 - val_my_metric_fn: -43.9358
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0185 - my_metric_fn: -27.9888 - val_loss: 0.0176 - val_my_metric_fn: -35.6251
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0151 - my_metric_fn: -22.5791 - val_loss: 0.0145 - val_my_metric_fn: -28.9410
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0123 - my_metric_fn: -18.2807 - val_loss: 0.0120 - val_my_metric_fn: -23.5513
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0101 - my_metric_fn: -14.8743 - val_loss: 0.0099 - val_my_metric_fn: -19.1959
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0084 - my_metric_fn: -12.0542 - val_loss: 0.0083 - val_my_metric_fn: -15.6684
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0069 - my_metric_fn: -9.8266 - val_loss: 0.0069 - val_my_metric_fn: -12.8075
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0058 - my_metric_fn: -7.9762 - val_loss: 0.0058 - val_my_metric_fn: -10.4816
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0048 - my_metric_fn: -6.5176 - val_loss: 0.0049 - val_my_metric_fn: -8.5872
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0144 - my_metric_fn: -0.2234 - val_loss: 0.0146 - val_my_metric_fn: -8.3086e-05
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: -2.2215e-04 - val_loss: 0.0145 - val_my_metric_fn: 0.0061
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0091 - val_loss: 0.0142 - val_my_metric_fn: 0.0217
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0116 - my_metric_fn: 0.0434 - val_loss: 0.0137 - val_my_metric_fn: 0.0428
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0110 - my_metric_fn: 0.0937 - val_loss: 0.0140 - val_my_metric_fn: 2.6778e-04
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0137 - my_metric_fn: 0.0629
# [0.013692657463252544, 0.06293321400880814]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 3ms/step - loss: 0.2304 - my_metric_fn: -360.2858 - val_loss: 0.2111 - val_my_metric_fn: -453.1241
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1936 - my_metric_fn: -301.6123 - val_loss: 0.1764 - val_my_metric_fn: -378.3369
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1606 - my_metric_fn: -250.8497 - val_loss: 0.1456 - val_my_metric_fn: -311.8720
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1317 - my_metric_fn: -205.8362 - val_loss: 0.1191 - val_my_metric_fn: -254.5745
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.1070 - my_metric_fn: -166.7890 - val_loss: 0.0968 - val_my_metric_fn: -206.4138
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0865 - my_metric_fn: -134.4609 - val_loss: 0.0784 - val_my_metric_fn: -166.6741
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0697 - my_metric_fn: -108.1471 - val_loss: 0.0634 - val_my_metric_fn: -134.2991
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0561 - my_metric_fn: -86.9379 - val_loss: 0.0513 - val_my_metric_fn: -108.1475
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0452 - my_metric_fn: -69.4249 - val_loss: 0.0415 - val_my_metric_fn: -87.1255
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0364 - my_metric_fn: -56.0373 - val_loss: 0.0337 - val_my_metric_fn: -70.2707
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0294 - my_metric_fn: -45.0561 - val_loss: 0.0274 - val_my_metric_fn: -56.7632
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0238 - my_metric_fn: -36.2178 - val_loss: 0.0224 - val_my_metric_fn: -45.9331
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0193 - my_metric_fn: -29.2173 - val_loss: 0.0183 - val_my_metric_fn: -37.2365
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0158 - my_metric_fn: -23.7244 - val_loss: 0.0151 - val_my_metric_fn: -30.2392
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0129 - my_metric_fn: -19.1457 - val_loss: 0.0124 - val_my_metric_fn: -24.6006
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0106 - my_metric_fn: -15.5800 - val_loss: 0.0103 - val_my_metric_fn: -20.0449
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0087 - my_metric_fn: -12.6079 - val_loss: 0.0086 - val_my_metric_fn: -16.3577
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0072 - my_metric_fn: -10.2486 - val_loss: 0.0072 - val_my_metric_fn: -13.3672
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0060 - my_metric_fn: -8.3536 - val_loss: 0.0060 - val_my_metric_fn: -10.9353
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 0.0050 - my_metric_fn: -6.8221 - val_loss: 0.0051 - val_my_metric_fn: -8.9555
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0147 - my_metric_fn: -0.2543 - val_loss: 0.0148 - val_my_metric_fn: -0.0163
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0059 - val_loss: 0.0146 - val_my_metric_fn: 0.0021
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 2.5085e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0032
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0013 - val_loss: 0.0146 - val_my_metric_fn: 0.0026
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0048
# [0.015659157186746597, 0.0048071169294416904]
# 2813/2813 [==============================] - 5s 2ms/step
#
# 0.1458439875976597

# %%
# Print out Predictive R^2
y_predict = yhat_df.mean(axis=1).values.reshape(-1)
y_real = merged_test_y

a = np.mean(np.square(y_predict -  y_real))
b = np.mean(np.square(y_real))
print(1-a/b)
# Out:
# 0.1458439875976597

# %% [markdown]
# ---

# %%
# Import Dataset
firm_df = pd.read_pickle('firm_df49.pkl')
firm_df.index = pd.to_datetime(firm_df.index).to_period('M')

# macro-economic variables
# There is one features which has 37 missing values but before year 1980
macro_df = pd.read_pickle('macro_df.pkl')
macro_df.index = pd.to_datetime(macro_df.index, format='%m/%d/%Y')
macro_df.rename(columns={"ep": "ep_macro"}, inplace=True)
macro_index = macro_df.index[1:]
macro_new = macro_df.iloc[:-1, :]
macro_new.index = macro_index
macro_new.index = macro_new.index.to_period('M')

# Scale macro-features
from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler(feature_range=(-0.5, 0.5))
#macro_scaled = scaler.fit_transform(macro_new)
#macro_scaled_df = pd.DataFrame(macro_scaled, columns=macro_new.columns)
#macro_scaled_df.index = macro_new.index

# merged data 1
merged_df = pd.merge(firm_df, macro_new, left_on='jdate', right_on='sasdate', how='inner')
merged_df.index = firm_df.index

# %%
char_core = ['acc','agr','beta','bm','cash','cashpr','cfp','chatoia','chcsho','chfeps','chinv',
       'chmom','chpmia','chtx','currat','depr','dy','ear','ep','gma','grcapx','grltnoa',
       'ill','indmom','invest','lev','lgr','maxret','mom12m','mom1m','mom36m','mve','nincr',
       'orgcap','pchgm_pchsale','pchsale_pchinvt','pchsale_pchrect','pchsale_pchxsga',
       'retvol','roaq','roavol','roeq','salecash','saleinv','sgr','sp','std_dolvol','std_turn','turn']

info_list = ['fyear','year','jyear','permno','ticker','comnam','exchcd','exchname','siccd',
       'indname','size_class','mve_m','rf','ret','ret_adj','ret_ex','ret_adj_ex',]

macro_col = ['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx','INDPRO', 'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD', 'IPNCONGD',
       'IPBUSEQ', 'IPMAT', 'IPDMAT', 'IPNMAT', 'IPMANSICS', 'IPB51222S','IPFUELS', 'CUMFNS', 'HWI', 'HWIURATIO', 'CLF16OV', 'CE16OV',
       'UNRATE', 'UEMPMEAN', 'UEMPLT5', 'UEMP5TO14', 'UEMP15OV','UEMP15T26', 'UEMP27OV', 'CLAIMSx', 'PAYEMS', 'USGOOD',
       'CES1021000001', 'USCONS', 'MANEMP', 'DMANEMP', 'NDMANEMP','SRVPRD', 'USTPU', 'USWTRADE', 'USTRADE', 'USFIRE', 'USGOVT',
       'CES0600000007', 'AWOTMAN', 'AWHMAN', 'HOUST', 'HOUSTNE','HOUSTMW', 'HOUSTS', 'HOUSTW', 'PERMIT', 'PERMITNE', 'PERMITMW',
       'PERMITS', 'PERMITW', 'AMDMNOx', 'ANDENOx', 'AMDMUOx', 'BUSINVx','ISRATIOx', 'M1SL', 'M2SL', 'M2REAL', 'BOGMBASE', 'TOTRESNS',
       'NONBORRES', 'BUSLOANS', 'REALLN', 'NONREVSL', 'CONSPI', 'S&P 500','S&P: indust', 'S&P div yield', 'S&P PE ratio', 'FEDFUNDS',
       'CP3Mx', 'TB3MS', 'TB6MS', 'GS1', 'GS5', 'GS10', 'AAA', 'BAA','COMPAPFFx', 'TB3SMFFM', 'TB6SMFFM', 'T1YFFM', 'T5YFFM', 'T10YFFM',
       'AAAFFM', 'BAAFFM', 'TWEXAFEGSMTHx', 'EXSZUSx', 'EXJPUSx','EXUSUKx', 'EXCAUSx', 'WPSFD49207', 'WPSFD49502', 'WPSID61',
       'WPSID62', 'OILPRICEx', 'PPICMM', 'CPIAUCSL', 'CPIAPPSL','CPITRNSL', 'CPIMEDSL', 'CUSR0000SAC', 'CUSR0000SAD',
       'CUSR0000SAS', 'CPIULFSL', 'CUSR0000SA0L2', 'CUSR0000SA0L5','PCEPI', 'DDURRG3M086SBEA', 'DNDGRG3M086SBEA', 'DSERRG3M086SBEA',
       'CES0600000008', 'CES2000000008', 'CES3000000008', 'UMCSENTx','DTCOLNVHFNM', 'DTCTHFNM', 'INVEST', 'VIXCLSx', 'dp', 'ep_macro', 'b/m',
       'ntis', 'tbl', 'tms', 'dfy', 'svar']

macro_core =  ['dp', 'ep_macro', 'b/m','ntis', 'tbl', 'tms', 'dfy', 'svar']

def datasplit(df, dataset):
    df_train = df[df.index < pd.Period((str(1995)+"-1"),freq='M')]
    df_val = df[(df.index >= pd.Period((str(1995)+"-1"),freq='M')) & (df.index < pd.Period((str(2000)+"-1"),freq='M'))]
    df_test = df[df.index >= pd.Period((str(2000)+"-1"),freq='M')]
    if dataset == "firm":
        X_train = df_train[char_core]
        X_val = df_val[char_core]
        X_test = df_test[char_core]
    elif dataset == 'macro':
        X_train = df_train[macro_col]
        X_val = df_val[macro_col]
        X_test = df_test[macro_col]
    elif dataset == "firm_macro":
        X_train = df_train[char_core+macro_col]
        X_val = df_val[char_core+macro_col]
        X_test = df_test[char_core+macro_col]
    elif dataset == "firm_macro8":
        X_train = df_train[char_core+macro_core]
        X_val = df_val[char_core+macro_core]
        X_test = df_test[char_core+macro_core] 
    y_train = df_train['predicted_return']
    y_val = df_val['predicted_return']
    y_test = df_test['predicted_return']
    return (X_train, y_train, X_val, y_val, X_test, y_test, )

# %%
merged_df.columns.tolist()[17:]
# merged data 1
firm_col = merged_df.columns.tolist()[17:17+49]
latent_col = merged_df.columns.tolist()[17+49+1:]
print(len(firm_col), len(latent_col))
# Out:
# 49 134

# %%
merged_latent = merged_df.copy()
df_train = merged_latent[merged_latent.index < pd.Period((str(1995)+"-1"),freq='M')]
df_val = merged_latent[(merged_latent.index >= pd.Period((str(1995)+"-1"),freq='M')) & (merged_latent.index < pd.Period((str(2000)+"-1"),freq='M'))]
df_test = merged_latent[merged_latent.index >= pd.Period((str(2000)+"-1"),freq='M')]

merged_train_firm = df_train[firm_col]
merged_train_latent = df_train[latent_col]
merged_train_y = df_train['predicted_return']
print(merged_train_firm.shape, merged_train_latent.shape, merged_train_y.shape)

merged_val_firm = df_val[firm_col]
merged_val_latent = df_val[latent_col]
merged_val_y = df_val['predicted_return']
print(merged_val_firm.shape, merged_val_latent.shape, merged_val_y.shape)

merged_test_firm = df_test[firm_col]
merged_test_latent = df_test[latent_col]
merged_test_y = df_test['predicted_return']
print(merged_test_firm.shape, merged_test_latent.shape, merged_test_y.shape)
# Out:
# (88347, 49) (88347, 134) (88347,)
# (31851, 49) (31851, 134) (31851,)
# (90007, 49) (90007, 134) (90007,)

# %%
def my_metric_fn(y_true, y_pred):
    num = tf.reduce_mean(tf.square(y_true - y_pred))
    den = tf.reduce_mean(tf.square(y_true))
    return 1 - num / den

def multi_input_model():
    l1_reg = 0.0
    l2_reg = 0.0
    dropout = 0.0
    lr = 0.0001
        
    # Define the hidden layers 
    input1 = Input(shape=(134,))
    x1 = Dense(6, activation='relu')(input1)
        
    # Input 2
    input2 = Input(shape=(49,))
    x2 = Dense(32, activation='relu')(input2)
    x2 = Dense(16, activation='relu')(x2)
    #x2 = Dense(8, activation='relu', kernel_regularizer=l1_l2(l1=l1_reg,l2=l2_reg))(x2)
    x2 = Dense(6, activation='relu')(x2)
        
    merged = Multiply()([x1, x2])
    output = Dense(1, activation='linear')(merged)
 
    # Create the model 
    model = Model(inputs=[input1, input2], outputs=output)
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(loss='mean_squared_error', optimizer=opt,metrics=[my_metric_fn])
    return model

# %%
def Autoencoder():
    input_img = Input(shape=(134, ))
    encoded1 = Dense(6, activation='sigmoid')(input_img)
    decoded1 = Dense(134, activation='sigmoid')(encoded1)
    
    autoencoder = Model(inputs=input_img, outputs=decoded1)
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    autoencoder.compile(loss='mean_squared_error', optimizer=opt, metrics=[my_metric_fn])
    return autoencoder

autoencoder = Autoencoder()

# %%
import random 

seed_list = [458, 165, 530, 564, 590, 560, 829, 170, 376, 176]
yhat_df = pd.DataFrame()

for random_seed in seed_list:
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)
    
    autoencoder = Autoencoder()
    autoencoder.fit(merged_train_latent, merged_train_latent,
                epochs = 20, batch_size = 256,
                validation_data = (merged_val_latent, merged_val_latent),
                 callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=1)])
 
    model = multi_input_model()
    model.layers[4].set_weights(autoencoder.layers[1].get_weights())
    model.layers[4].trainable = False
    model.fit([merged_train_latent, merged_train_firm], merged_train_y,
                   epochs=50,
                   validation_data=([merged_val_latent, merged_val_firm], merged_val_y),
                   callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=1)])
    print(model.evaluate([merged_test_latent, merged_test_firm], merged_test_y))
    y_hat = model.predict([merged_test_latent, merged_test_firm]).reshape(-1)
    yhat_df[random_seed] = y_hat
    print()

# Print out Predictive R^2
y_predict = yhat_df.mean(axis=1).values.reshape(-1)
y_real = merged_test_y

a = np.mean(np.square(y_predict -  y_real))
b = np.mean(np.square(y_real))
print(1-a/b)
# Out:
# Epoch 1/20
# 410/410 [==============================] - 2s 5ms/step - loss: 139.4794 - my_metric_fn: 0.0086 - val_loss: 272.2100 - val_my_metric_fn: 0.0126
# Epoch 2/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.1864 - my_metric_fn: 0.0107 - val_loss: 271.9395 - val_my_metric_fn: 0.0150
# Epoch 3/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.9742 - my_metric_fn: 0.0122 - val_loss: 271.7515 - val_my_metric_fn: 0.0167
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.8177 - my_metric_fn: 0.0133 - val_loss: 271.6062 - val_my_metric_fn: 0.0181
# Epoch 5/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.6937 - my_metric_fn: 0.0142 - val_loss: 271.4890 - val_my_metric_fn: 0.0191
# Epoch 6/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.5941 - my_metric_fn: 0.0150 - val_loss: 271.3937 - val_my_metric_fn: 0.0200
# Epoch 7/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.5127 - my_metric_fn: 0.0156 - val_loss: 271.3153 - val_my_metric_fn: 0.0207
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.4458 - my_metric_fn: 0.0159 - val_loss: 271.2500 - val_my_metric_fn: 0.0213
# Epoch 9/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.3900 - my_metric_fn: 0.0164 - val_loss: 271.1950 - val_my_metric_fn: 0.0217
# Epoch 10/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3425 - my_metric_fn: 0.0167 - val_loss: 271.1479 - val_my_metric_fn: 0.0222
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3016 - my_metric_fn: 0.0170 - val_loss: 271.1067 - val_my_metric_fn: 0.0225
# Epoch 12/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.2658 - my_metric_fn: 0.0173 - val_loss: 271.0696 - val_my_metric_fn: 0.0228
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2345 - my_metric_fn: 0.0175 - val_loss: 271.0361 - val_my_metric_fn: 0.0231
# Epoch 14/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2065 - my_metric_fn: 0.0177 - val_loss: 271.0059 - val_my_metric_fn: 0.0234
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1815 - my_metric_fn: 0.0179 - val_loss: 270.9788 - val_my_metric_fn: 0.0236
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1591 - my_metric_fn: 0.0180 - val_loss: 270.9541 - val_my_metric_fn: 0.0238
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1391 - my_metric_fn: 0.0182 - val_loss: 270.9315 - val_my_metric_fn: 0.0240
# Epoch 18/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1208 - my_metric_fn: 0.0183 - val_loss: 270.9110 - val_my_metric_fn: 0.0242
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1042 - my_metric_fn: 0.0184 - val_loss: 270.8918 - val_my_metric_fn: 0.0243
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0890 - my_metric_fn: 0.0185 - val_loss: 270.8734 - val_my_metric_fn: 0.0245
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 1.0405 - my_metric_fn: -105.0446 - val_loss: 0.1182 - val_my_metric_fn: -9.8042
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0226 - my_metric_fn: -1.1024 - val_loss: 0.0406 - val_my_metric_fn: -2.3632
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0133 - my_metric_fn: -0.1068 - val_loss: 0.0271 - val_my_metric_fn: -1.1000
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0123 - my_metric_fn: -0.0138 - val_loss: 0.0223 - val_my_metric_fn: -0.6595
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: -1.2545e-04 - val_loss: 0.0206 - val_my_metric_fn: -0.5145
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0016 - val_loss: 0.0201 - val_my_metric_fn: -0.4820
# Epoch 7/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0017 - val_loss: 0.0199 - val_my_metric_fn: -0.4743
# Epoch 8/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0031 - val_loss: 0.0204 - val_my_metric_fn: -0.5338
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0205 - my_metric_fn: -0.8341
# [0.020512264221906662, -0.8341036438941956]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.4547 - my_metric_fn: 0.0087 - val_loss: 272.1776 - val_my_metric_fn: 0.0128
# Epoch 2/20
# 410/410 [==============================] - 2s 5ms/step - loss: 139.1686 - my_metric_fn: 0.0108 - val_loss: 271.8931 - val_my_metric_fn: 0.0157
# Epoch 3/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.9297 - my_metric_fn: 0.0126 - val_loss: 271.6852 - val_my_metric_fn: 0.0177
# Epoch 4/20
# 410/410 [==============================] - 2s 6ms/step - loss: 138.7504 - my_metric_fn: 0.0138 - val_loss: 271.5340 - val_my_metric_fn: 0.0191
# Epoch 5/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.6315 - my_metric_fn: 0.0147 - val_loss: 271.4232 - val_my_metric_fn: 0.0200
# Epoch 6/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.5384 - my_metric_fn: 0.0153 - val_loss: 271.3326 - val_my_metric_fn: 0.0208
# Epoch 7/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.4609 - my_metric_fn: 0.0159 - val_loss: 271.2470 - val_my_metric_fn: 0.0214
# Epoch 8/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3898 - my_metric_fn: 0.0163 - val_loss: 271.1677 - val_my_metric_fn: 0.0220
# Epoch 9/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.3264 - my_metric_fn: 0.0168 - val_loss: 271.0993 - val_my_metric_fn: 0.0225
# Epoch 10/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2716 - my_metric_fn: 0.0172 - val_loss: 271.0405 - val_my_metric_fn: 0.0229
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2238 - my_metric_fn: 0.0176 - val_loss: 270.9865 - val_my_metric_fn: 0.0233
# Epoch 12/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1795 - my_metric_fn: 0.0179 - val_loss: 270.9293 - val_my_metric_fn: 0.0236
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1341 - my_metric_fn: 0.0182 - val_loss: 270.8714 - val_my_metric_fn: 0.0240
# Epoch 14/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0908 - my_metric_fn: 0.0185 - val_loss: 270.8188 - val_my_metric_fn: 0.0243
# Epoch 15/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0513 - my_metric_fn: 0.0188 - val_loss: 270.7713 - val_my_metric_fn: 0.0246
# Epoch 16/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0154 - my_metric_fn: 0.0190 - val_loss: 270.7278 - val_my_metric_fn: 0.0249
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.9827 - my_metric_fn: 0.0192 - val_loss: 270.6874 - val_my_metric_fn: 0.0252
# Epoch 18/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.9528 - my_metric_fn: 0.0195 - val_loss: 270.6499 - val_my_metric_fn: 0.0254
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.9250 - my_metric_fn: 0.0196 - val_loss: 270.6150 - val_my_metric_fn: 0.0257
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.8994 - my_metric_fn: 0.0199 - val_loss: 270.5826 - val_my_metric_fn: 0.0259
# Epoch 1/50
# 2761/2761 [==============================] - 12s 4ms/step - loss: 1.4937 - my_metric_fn: -149.3018 - val_loss: 0.0585 - val_my_metric_fn: -4.4595
# Epoch 2/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0236 - my_metric_fn: -1.1706 - val_loss: 0.0195 - val_my_metric_fn: -0.4946
# Epoch 3/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0133 - my_metric_fn: -0.1173 - val_loss: 0.0151 - val_my_metric_fn: -0.0576
# Epoch 4/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0122 - my_metric_fn: -0.0126 - val_loss: 0.0146 - val_my_metric_fn: -0.0035
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: -4.6103e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0030
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0013 - val_loss: 0.0146 - val_my_metric_fn: 0.0041
# Epoch 7/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0024 - val_loss: 0.0146 - val_my_metric_fn: 9.8248e-04
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0158 - my_metric_fn: -0.0134
# [0.015801146626472473, -0.013388097286224365]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.4989 - my_metric_fn: 0.0084 - val_loss: 272.1981 - val_my_metric_fn: 0.0125
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 139.2275 - my_metric_fn: 0.0104 - val_loss: 271.9663 - val_my_metric_fn: 0.0147
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 139.0273 - my_metric_fn: 0.0118 - val_loss: 271.7787 - val_my_metric_fn: 0.0165
# Epoch 4/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.8594 - my_metric_fn: 0.0130 - val_loss: 271.6191 - val_my_metric_fn: 0.0179
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.7204 - my_metric_fn: 0.0140 - val_loss: 271.4839 - val_my_metric_fn: 0.0191
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.6046 - my_metric_fn: 0.0148 - val_loss: 271.3696 - val_my_metric_fn: 0.0201
# Epoch 7/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.5076 - my_metric_fn: 0.0155 - val_loss: 271.2723 - val_my_metric_fn: 0.0209
# Epoch 8/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.4257 - my_metric_fn: 0.0161 - val_loss: 271.1886 - val_my_metric_fn: 0.0216
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.3557 - my_metric_fn: 0.0166 - val_loss: 271.1160 - val_my_metric_fn: 0.0221
# Epoch 10/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.2951 - my_metric_fn: 0.0171 - val_loss: 271.0522 - val_my_metric_fn: 0.0226
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.2421 - my_metric_fn: 0.0174 - val_loss: 270.9955 - val_my_metric_fn: 0.0231
# Epoch 12/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.1953 - my_metric_fn: 0.0177 - val_loss: 270.9444 - val_my_metric_fn: 0.0235
# Epoch 13/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.1537 - my_metric_fn: 0.0181 - val_loss: 270.8986 - val_my_metric_fn: 0.0238
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1165 - my_metric_fn: 0.0183 - val_loss: 270.8573 - val_my_metric_fn: 0.0241
# Epoch 15/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.0829 - my_metric_fn: 0.0185 - val_loss: 270.8192 - val_my_metric_fn: 0.0244
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0525 - my_metric_fn: 0.0188 - val_loss: 270.7841 - val_my_metric_fn: 0.0247
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0247 - my_metric_fn: 0.0189 - val_loss: 270.7518 - val_my_metric_fn: 0.0249
# Epoch 18/20
# 410/410 [==============================] - 1s 4ms/step - loss: 137.9993 - my_metric_fn: 0.0191 - val_loss: 270.7217 - val_my_metric_fn: 0.0251
# Epoch 19/20
# 410/410 [==============================] - 1s 4ms/step - loss: 137.9760 - my_metric_fn: 0.0194 - val_loss: 270.6938 - val_my_metric_fn: 0.0253
# Epoch 20/20
# 410/410 [==============================] - 1s 4ms/step - loss: 137.9545 - my_metric_fn: 0.0195 - val_loss: 270.6677 - val_my_metric_fn: 0.0255
# Epoch 1/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.5334 - my_metric_fn: -55.1687 - val_loss: 0.0386 - val_my_metric_fn: -2.6094
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0156 - my_metric_fn: -0.3450 - val_loss: 0.0194 - val_my_metric_fn: -0.5495
# Epoch 3/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0124 - my_metric_fn: -0.0289 - val_loss: 0.0161 - val_my_metric_fn: -0.1691
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 2.4875e-04 - val_loss: 0.0152 - val_my_metric_fn: -0.0645
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0055 - val_loss: 0.0149 - val_my_metric_fn: -0.0236
# Epoch 6/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0097 - val_loss: 0.0150 - val_my_metric_fn: -0.0325
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0198 - my_metric_fn: -0.5778
# [0.01982075162231922, -0.5777627825737]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.5527 - my_metric_fn: 0.0081 - val_loss: 272.3005 - val_my_metric_fn: 0.0117
# Epoch 2/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.3313 - my_metric_fn: 0.0097 - val_loss: 272.1026 - val_my_metric_fn: 0.0134
# Epoch 3/20
# 410/410 [==============================] - 1s 4ms/step - loss: 139.1674 - my_metric_fn: 0.0108 - val_loss: 271.9474 - val_my_metric_fn: 0.0149
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.0298 - my_metric_fn: 0.0118 - val_loss: 271.8168 - val_my_metric_fn: 0.0162
# Epoch 5/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.9113 - my_metric_fn: 0.0126 - val_loss: 271.7041 - val_my_metric_fn: 0.0173
# Epoch 6/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.8092 - my_metric_fn: 0.0134 - val_loss: 271.6061 - val_my_metric_fn: 0.0182
# Epoch 7/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.7208 - my_metric_fn: 0.0140 - val_loss: 271.5192 - val_my_metric_fn: 0.0190
# Epoch 8/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.6433 - my_metric_fn: 0.0146 - val_loss: 271.4388 - val_my_metric_fn: 0.0197
# Epoch 9/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.5738 - my_metric_fn: 0.0151 - val_loss: 271.3646 - val_my_metric_fn: 0.0203
# Epoch 10/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.5096 - my_metric_fn: 0.0156 - val_loss: 271.2928 - val_my_metric_fn: 0.0208
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.4496 - my_metric_fn: 0.0159 - val_loss: 271.2264 - val_my_metric_fn: 0.0213
# Epoch 12/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3940 - my_metric_fn: 0.0163 - val_loss: 271.1644 - val_my_metric_fn: 0.0218
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3423 - my_metric_fn: 0.0167 - val_loss: 271.1064 - val_my_metric_fn: 0.0222
# Epoch 14/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2946 - my_metric_fn: 0.0171 - val_loss: 271.0528 - val_my_metric_fn: 0.0226
# Epoch 15/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2504 - my_metric_fn: 0.0173 - val_loss: 271.0033 - val_my_metric_fn: 0.0230
# Epoch 16/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2095 - my_metric_fn: 0.0176 - val_loss: 270.9575 - val_my_metric_fn: 0.0233
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1717 - my_metric_fn: 0.0179 - val_loss: 270.9149 - val_my_metric_fn: 0.0236
# Epoch 18/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1368 - my_metric_fn: 0.0182 - val_loss: 270.8751 - val_my_metric_fn: 0.0239
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1045 - my_metric_fn: 0.0184 - val_loss: 270.8375 - val_my_metric_fn: 0.0242
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0744 - my_metric_fn: 0.0187 - val_loss: 270.8022 - val_my_metric_fn: 0.0244
# Epoch 1/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.6246 - my_metric_fn: -61.1073 - val_loss: 0.0635 - val_my_metric_fn: -4.6939
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0189 - my_metric_fn: -0.6654 - val_loss: 0.0211 - val_my_metric_fn: -0.7267
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0130 - my_metric_fn: -0.0880 - val_loss: 0.0163 - val_my_metric_fn: -0.2253
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0110 - val_loss: 0.0152 - val_my_metric_fn: -0.1054
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0012 - val_loss: 0.0152 - val_my_metric_fn: -0.1014
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0044 - val_loss: 0.0152 - val_my_metric_fn: -0.0920
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0171 - my_metric_fn: -0.1244
# [0.01707121729850769, -0.12440617382526398]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.5035 - my_metric_fn: 0.0084 - val_loss: 272.2508 - val_my_metric_fn: 0.0114
# Epoch 2/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.3427 - my_metric_fn: 0.0095 - val_loss: 272.0892 - val_my_metric_fn: 0.0129
# Epoch 3/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.1902 - my_metric_fn: 0.0107 - val_loss: 271.9331 - val_my_metric_fn: 0.0144
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.0373 - my_metric_fn: 0.0118 - val_loss: 271.7846 - val_my_metric_fn: 0.0159
# Epoch 5/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.9039 - my_metric_fn: 0.0127 - val_loss: 271.6616 - val_my_metric_fn: 0.0170
# Epoch 6/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.7931 - my_metric_fn: 0.0135 - val_loss: 271.5547 - val_my_metric_fn: 0.0180
# Epoch 7/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.6975 - my_metric_fn: 0.0141 - val_loss: 271.4598 - val_my_metric_fn: 0.0189
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.6134 - my_metric_fn: 0.0148 - val_loss: 271.3741 - val_my_metric_fn: 0.0196
# Epoch 9/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.5383 - my_metric_fn: 0.0154 - val_loss: 271.2948 - val_my_metric_fn: 0.0203
# Epoch 10/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.4703 - my_metric_fn: 0.0158 - val_loss: 271.2203 - val_my_metric_fn: 0.0209
# Epoch 11/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.4078 - my_metric_fn: 0.0162 - val_loss: 271.1490 - val_my_metric_fn: 0.0214
# Epoch 12/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.3493 - my_metric_fn: 0.0167 - val_loss: 271.0811 - val_my_metric_fn: 0.0219
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2939 - my_metric_fn: 0.0170 - val_loss: 271.0165 - val_my_metric_fn: 0.0224
# Epoch 14/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.2417 - my_metric_fn: 0.0174 - val_loss: 270.9554 - val_my_metric_fn: 0.0228
# Epoch 15/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.1926 - my_metric_fn: 0.0178 - val_loss: 270.8981 - val_my_metric_fn: 0.0232
# Epoch 16/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1467 - my_metric_fn: 0.0181 - val_loss: 270.8438 - val_my_metric_fn: 0.0236
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1036 - my_metric_fn: 0.0184 - val_loss: 270.7931 - val_my_metric_fn: 0.0240
# Epoch 18/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0635 - my_metric_fn: 0.0186 - val_loss: 270.7458 - val_my_metric_fn: 0.0243
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0263 - my_metric_fn: 0.0190 - val_loss: 270.7016 - val_my_metric_fn: 0.0246
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.9917 - my_metric_fn: 0.0192 - val_loss: 270.6602 - val_my_metric_fn: 0.0249
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0542 - my_metric_fn: -4.2634 - val_loss: 0.0185 - val_my_metric_fn: -0.4585
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0123 - my_metric_fn: -0.0167 - val_loss: 0.0174 - val_my_metric_fn: -0.3577
# Epoch 3/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: -3.9338e-04 - val_loss: 0.0170 - val_my_metric_fn: -0.3095
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0011 - val_loss: 0.0169 - val_my_metric_fn: -0.2964
# Epoch 5/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0019 - val_loss: 0.0169 - val_my_metric_fn: -0.3015
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0178 - my_metric_fn: -0.1893
# [0.017846452072262764, -0.1893465220928192]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.4987 - my_metric_fn: 0.0084 - val_loss: 272.2465 - val_my_metric_fn: 0.0120
# Epoch 2/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.3193 - my_metric_fn: 0.0097 - val_loss: 272.0829 - val_my_metric_fn: 0.0136
# Epoch 3/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.1689 - my_metric_fn: 0.0108 - val_loss: 271.9362 - val_my_metric_fn: 0.0150
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.0319 - my_metric_fn: 0.0118 - val_loss: 271.8066 - val_my_metric_fn: 0.0163
# Epoch 5/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.9108 - my_metric_fn: 0.0126 - val_loss: 271.6918 - val_my_metric_fn: 0.0174
# Epoch 6/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.8056 - my_metric_fn: 0.0134 - val_loss: 271.5899 - val_my_metric_fn: 0.0184
# Epoch 7/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.7141 - my_metric_fn: 0.0141 - val_loss: 271.4977 - val_my_metric_fn: 0.0192
# Epoch 8/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.6333 - my_metric_fn: 0.0146 - val_loss: 271.4127 - val_my_metric_fn: 0.0199
# Epoch 9/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.5609 - my_metric_fn: 0.0151 - val_loss: 271.3335 - val_my_metric_fn: 0.0206
# Epoch 10/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.4954 - my_metric_fn: 0.0157 - val_loss: 271.2604 - val_my_metric_fn: 0.0211
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.4360 - my_metric_fn: 0.0160 - val_loss: 271.1928 - val_my_metric_fn: 0.0216
# Epoch 12/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3810 - my_metric_fn: 0.0164 - val_loss: 271.1305 - val_my_metric_fn: 0.0221
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3302 - my_metric_fn: 0.0168 - val_loss: 271.0729 - val_my_metric_fn: 0.0225
# Epoch 14/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2831 - my_metric_fn: 0.0171 - val_loss: 271.0200 - val_my_metric_fn: 0.0229
# Epoch 15/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2399 - my_metric_fn: 0.0174 - val_loss: 270.9712 - val_my_metric_fn: 0.0232
# Epoch 16/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1928 - my_metric_fn: 0.0178 - val_loss: 270.8855 - val_my_metric_fn: 0.0237
# Epoch 17/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1230 - my_metric_fn: 0.0182 - val_loss: 270.8177 - val_my_metric_fn: 0.0242
# Epoch 18/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0736 - my_metric_fn: 0.0186 - val_loss: 270.7639 - val_my_metric_fn: 0.0245
# Epoch 19/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0319 - my_metric_fn: 0.0189 - val_loss: 270.7163 - val_my_metric_fn: 0.0248
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.9948 - my_metric_fn: 0.0192 - val_loss: 270.6736 - val_my_metric_fn: 0.0251
# Epoch 1/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 1.2007 - my_metric_fn: -125.1322 - val_loss: 0.0381 - val_my_metric_fn: -2.3418
# Epoch 2/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0164 - my_metric_fn: -0.4234 - val_loss: 0.0171 - val_my_metric_fn: -0.2553
# Epoch 3/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0125 - my_metric_fn: -0.0411 - val_loss: 0.0151 - val_my_metric_fn: -0.0469
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0041 - val_loss: 0.0147 - val_my_metric_fn: -0.0113
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0014 - val_loss: 0.0147 - val_my_metric_fn: -0.0017
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0021 - val_loss: 0.0146 - val_my_metric_fn: -9.9964e-04
# Epoch 7/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0031 - val_loss: 0.0146 - val_my_metric_fn: -7.6093e-04
# Epoch 8/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0029 - val_loss: 0.0146 - val_my_metric_fn: 0.0025
# Epoch 9/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0047 - val_loss: 0.0146 - val_my_metric_fn: 4.8470e-04
# 2813/2813 [==============================] - 6s 2ms/step - loss: 0.0158 - my_metric_fn: -0.0143
# [0.015808258205652237, -0.014320552349090576]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.5859 - my_metric_fn: 0.0078 - val_loss: 272.3635 - val_my_metric_fn: 0.0114
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 139.3687 - my_metric_fn: 0.0094 - val_loss: 272.1593 - val_my_metric_fn: 0.0132
# Epoch 3/20
# 410/410 [==============================] - 1s 3ms/step - loss: 139.1556 - my_metric_fn: 0.0110 - val_loss: 271.9083 - val_my_metric_fn: 0.0152
# Epoch 4/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.9694 - my_metric_fn: 0.0122 - val_loss: 271.7396 - val_my_metric_fn: 0.0168
# Epoch 5/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.8273 - my_metric_fn: 0.0133 - val_loss: 271.6018 - val_my_metric_fn: 0.0180
# Epoch 6/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.7101 - my_metric_fn: 0.0141 - val_loss: 271.4856 - val_my_metric_fn: 0.0191
# Epoch 7/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.6111 - my_metric_fn: 0.0148 - val_loss: 271.3858 - val_my_metric_fn: 0.0199
# Epoch 8/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.5261 - my_metric_fn: 0.0153 - val_loss: 271.2985 - val_my_metric_fn: 0.0206
# Epoch 9/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.4522 - my_metric_fn: 0.0159 - val_loss: 271.2212 - val_my_metric_fn: 0.0213
# Epoch 10/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.3872 - my_metric_fn: 0.0164 - val_loss: 271.1523 - val_my_metric_fn: 0.0218
# Epoch 11/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.3292 - my_metric_fn: 0.0168 - val_loss: 271.0900 - val_my_metric_fn: 0.0223
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.2769 - my_metric_fn: 0.0172 - val_loss: 271.0334 - val_my_metric_fn: 0.0227
# Epoch 13/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.2298 - my_metric_fn: 0.0175 - val_loss: 270.9819 - val_my_metric_fn: 0.0231
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1871 - my_metric_fn: 0.0178 - val_loss: 270.9345 - val_my_metric_fn: 0.0235
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1486 - my_metric_fn: 0.0181 - val_loss: 270.8908 - val_my_metric_fn: 0.0238
# Epoch 16/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.1133 - my_metric_fn: 0.0183 - val_loss: 270.8505 - val_my_metric_fn: 0.0241
# Epoch 17/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.0810 - my_metric_fn: 0.0186 - val_loss: 270.8133 - val_my_metric_fn: 0.0244
# Epoch 18/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.0514 - my_metric_fn: 0.0188 - val_loss: 270.7787 - val_my_metric_fn: 0.0246
# Epoch 19/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.0241 - my_metric_fn: 0.0190 - val_loss: 270.7466 - val_my_metric_fn: 0.0249
# Epoch 20/20
# 410/410 [==============================] - 1s 4ms/step - loss: 137.9990 - my_metric_fn: 0.0191 - val_loss: 270.7165 - val_my_metric_fn: 0.0251
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.4420 - my_metric_fn: -45.4277 - val_loss: 0.0297 - val_my_metric_fn: -1.5053
# Epoch 2/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0148 - my_metric_fn: -0.2770 - val_loss: 0.0163 - val_my_metric_fn: -0.1745
# Epoch 3/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0124 - my_metric_fn: -0.0299 - val_loss: 0.0149 - val_my_metric_fn: -0.0333
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0022 - val_loss: 0.0147 - val_my_metric_fn: -0.0049
# Epoch 5/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0012 - val_loss: 0.0146 - val_my_metric_fn: -7.0634e-04
# Epoch 6/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0014 - val_loss: 0.0147 - val_my_metric_fn: -0.0034
# 2813/2813 [==============================] - 7s 3ms/step - loss: 0.7871 - my_metric_fn: -90.3853
# [0.7870595455169678, -90.38534545898438]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 5ms/step - loss: 139.4876 - my_metric_fn: 0.0086 - val_loss: 272.2388 - val_my_metric_fn: 0.0119
# Epoch 2/20
# 410/410 [==============================] - 2s 6ms/step - loss: 139.2970 - my_metric_fn: 0.0099 - val_loss: 272.0279 - val_my_metric_fn: 0.0140
# Epoch 3/20
# 410/410 [==============================] - 2s 5ms/step - loss: 139.0897 - my_metric_fn: 0.0113 - val_loss: 271.8095 - val_my_metric_fn: 0.0160
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.9147 - my_metric_fn: 0.0126 - val_loss: 271.6550 - val_my_metric_fn: 0.0175
# Epoch 5/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.7814 - my_metric_fn: 0.0135 - val_loss: 271.5272 - val_my_metric_fn: 0.0187
# Epoch 6/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.6704 - my_metric_fn: 0.0144 - val_loss: 271.4176 - val_my_metric_fn: 0.0197
# Epoch 7/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.5762 - my_metric_fn: 0.0150 - val_loss: 271.3210 - val_my_metric_fn: 0.0205
# Epoch 8/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.4947 - my_metric_fn: 0.0156 - val_loss: 271.2344 - val_my_metric_fn: 0.0212
# Epoch 9/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.4229 - my_metric_fn: 0.0161 - val_loss: 271.1551 - val_my_metric_fn: 0.0218
# Epoch 10/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3584 - my_metric_fn: 0.0166 - val_loss: 271.0804 - val_my_metric_fn: 0.0224
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2944 - my_metric_fn: 0.0170 - val_loss: 270.9949 - val_my_metric_fn: 0.0229
# Epoch 12/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.2320 - my_metric_fn: 0.0175 - val_loss: 270.9208 - val_my_metric_fn: 0.0234
# Epoch 13/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1749 - my_metric_fn: 0.0179 - val_loss: 270.8532 - val_my_metric_fn: 0.0238
# Epoch 14/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1225 - my_metric_fn: 0.0182 - val_loss: 270.7914 - val_my_metric_fn: 0.0242
# Epoch 15/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.0743 - my_metric_fn: 0.0186 - val_loss: 270.7323 - val_my_metric_fn: 0.0245
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0275 - my_metric_fn: 0.0190 - val_loss: 270.6721 - val_my_metric_fn: 0.0248
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9836 - my_metric_fn: 0.0193 - val_loss: 270.6175 - val_my_metric_fn: 0.0252
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9426 - my_metric_fn: 0.0196 - val_loss: 270.5671 - val_my_metric_fn: 0.0255
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9044 - my_metric_fn: 0.0198 - val_loss: 270.5206 - val_my_metric_fn: 0.0257
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8693 - my_metric_fn: 0.0201 - val_loss: 270.4781 - val_my_metric_fn: 0.0260
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.1002 - my_metric_fn: -8.9482 - val_loss: 0.0167 - val_my_metric_fn: -0.1966
# Epoch 2/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0127 - my_metric_fn: -0.0555 - val_loss: 0.0149 - val_my_metric_fn: -0.0248
# Epoch 3/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0065 - val_loss: 0.0146 - val_my_metric_fn: 2.3873e-04
# Epoch 4/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 1.0658e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0018
# Epoch 5/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0015 - val_loss: 0.0146 - val_my_metric_fn: 0.0030
# Epoch 6/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0019 - val_loss: 0.0146 - val_my_metric_fn: 0.0033
# Epoch 7/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0024 - val_loss: 0.0147 - val_my_metric_fn: -0.0053
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0168 - my_metric_fn: -0.0847
# [0.016817277297377586, -0.08467233180999756]
# 2813/2813 [==============================] - 5s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 3s 4ms/step - loss: 139.4891 - my_metric_fn: 0.0085 - val_loss: 272.2160 - val_my_metric_fn: 0.0117
# Epoch 2/20
# 410/410 [==============================] - 1s 3ms/step - loss: 139.2783 - my_metric_fn: 0.0100 - val_loss: 271.9872 - val_my_metric_fn: 0.0140
# Epoch 3/20
# 410/410 [==============================] - 1s 4ms/step - loss: 139.0435 - my_metric_fn: 0.0117 - val_loss: 271.7426 - val_my_metric_fn: 0.0165
# Epoch 4/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.8347 - my_metric_fn: 0.0132 - val_loss: 271.5663 - val_my_metric_fn: 0.0181
# Epoch 5/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.6877 - my_metric_fn: 0.0142 - val_loss: 271.4248 - val_my_metric_fn: 0.0194
# Epoch 6/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.5690 - my_metric_fn: 0.0150 - val_loss: 271.3041 - val_my_metric_fn: 0.0204
# Epoch 7/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.4688 - my_metric_fn: 0.0158 - val_loss: 271.1978 - val_my_metric_fn: 0.0212
# Epoch 8/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.3818 - my_metric_fn: 0.0165 - val_loss: 271.1023 - val_my_metric_fn: 0.0219
# Epoch 9/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.3049 - my_metric_fn: 0.0171 - val_loss: 271.0154 - val_my_metric_fn: 0.0225
# Epoch 10/20
# 410/410 [==============================] - 1s 4ms/step - loss: 138.2355 - my_metric_fn: 0.0174 - val_loss: 270.9359 - val_my_metric_fn: 0.0231
# Epoch 11/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1721 - my_metric_fn: 0.0179 - val_loss: 270.8631 - val_my_metric_fn: 0.0236
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.1145 - my_metric_fn: 0.0184 - val_loss: 270.7964 - val_my_metric_fn: 0.0240
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0619 - my_metric_fn: 0.0187 - val_loss: 270.7350 - val_my_metric_fn: 0.0244
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0139 - my_metric_fn: 0.0190 - val_loss: 270.6787 - val_my_metric_fn: 0.0248
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9702 - my_metric_fn: 0.0194 - val_loss: 270.6270 - val_my_metric_fn: 0.0252
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9306 - my_metric_fn: 0.0197 - val_loss: 270.5799 - val_my_metric_fn: 0.0255
# Epoch 17/20
# 410/410 [==============================] - 1s 4ms/step - loss: 137.8944 - my_metric_fn: 0.0199 - val_loss: 270.5367 - val_my_metric_fn: 0.0258
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8615 - my_metric_fn: 0.0201 - val_loss: 270.4972 - val_my_metric_fn: 0.0261
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8314 - my_metric_fn: 0.0203 - val_loss: 270.4611 - val_my_metric_fn: 0.0263
# Epoch 20/20
# 410/410 [==============================] - 2s 4ms/step - loss: 137.8040 - my_metric_fn: 0.0205 - val_loss: 270.4278 - val_my_metric_fn: 0.0265
# Epoch 1/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.6863 - my_metric_fn: -68.1004 - val_loss: 0.0505 - val_my_metric_fn: -3.4453
# Epoch 2/50
# 2761/2761 [==============================] - 11s 4ms/step - loss: 0.0184 - my_metric_fn: -0.6525 - val_loss: 0.0184 - val_my_metric_fn: -0.3720
# Epoch 3/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0129 - my_metric_fn: -0.0721 - val_loss: 0.0151 - val_my_metric_fn: -0.0557
# Epoch 4/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0122 - my_metric_fn: -0.0096 - val_loss: 0.0146 - val_my_metric_fn: -0.0049
# Epoch 5/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0121 - my_metric_fn: -4.5345e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0016
# Epoch 6/50
# 2761/2761 [==============================] - 10s 3ms/step - loss: 0.0121 - my_metric_fn: 7.3015e-04 - val_loss: 0.0146 - val_my_metric_fn: 0.0042
# Epoch 7/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0011 - val_loss: 0.0146 - val_my_metric_fn: 0.0045
# Epoch 8/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0013 - val_loss: 0.0146 - val_my_metric_fn: 0.0044
# Epoch 9/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0121 - my_metric_fn: 0.0018 - val_loss: 0.0146 - val_my_metric_fn: 0.0048
# Epoch 10/50
# 2761/2761 [==============================] - 10s 4ms/step - loss: 0.0121 - my_metric_fn: 0.0017 - val_loss: 0.0146 - val_my_metric_fn: 0.0044
# 2813/2813 [==============================] - 7s 2ms/step - loss: 0.0157 - my_metric_fn: 0.0051
# [0.015692949295043945, 0.00512668676674366]
# 2813/2813 [==============================] - 6s 2ms/step
#
# Epoch 1/20
# 410/410 [==============================] - 2s 4ms/step - loss: 139.4038 - my_metric_fn: 0.0091 - val_loss: 272.0930 - val_my_metric_fn: 0.0127
# Epoch 2/20
# 410/410 [==============================] - 2s 5ms/step - loss: 139.1804 - my_metric_fn: 0.0107 - val_loss: 271.8618 - val_my_metric_fn: 0.0152
# Epoch 3/20
# 410/410 [==============================] - 4s 11ms/step - loss: 138.9709 - my_metric_fn: 0.0122 - val_loss: 271.6700 - val_my_metric_fn: 0.0171
# Epoch 4/20
# 410/410 [==============================] - 2s 5ms/step - loss: 138.8048 - my_metric_fn: 0.0134 - val_loss: 271.5187 - val_my_metric_fn: 0.0186
# Epoch 5/20
# 410/410 [==============================] - 4s 11ms/step - loss: 138.6699 - my_metric_fn: 0.0144 - val_loss: 271.3874 - val_my_metric_fn: 0.0198
# Epoch 6/20
# 410/410 [==============================] - 3s 8ms/step - loss: 138.5573 - my_metric_fn: 0.0152 - val_loss: 271.2715 - val_my_metric_fn: 0.0208
# Epoch 7/20
# 410/410 [==============================] - 4s 9ms/step - loss: 138.4595 - my_metric_fn: 0.0159 - val_loss: 271.1675 - val_my_metric_fn: 0.0216
# Epoch 8/20
# 410/410 [==============================] - 3s 8ms/step - loss: 138.3721 - my_metric_fn: 0.0165 - val_loss: 271.0721 - val_my_metric_fn: 0.0223
# Epoch 9/20
# 410/410 [==============================] - 3s 7ms/step - loss: 138.2914 - my_metric_fn: 0.0170 - val_loss: 270.9831 - val_my_metric_fn: 0.0229
# Epoch 10/20
# 410/410 [==============================] - 3s 7ms/step - loss: 138.2167 - my_metric_fn: 0.0176 - val_loss: 270.8987 - val_my_metric_fn: 0.0234
# Epoch 11/20
# 410/410 [==============================] - 2s 4ms/step - loss: 138.1501 - my_metric_fn: 0.0180 - val_loss: 270.8226 - val_my_metric_fn: 0.0239
# Epoch 12/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0910 - my_metric_fn: 0.0186 - val_loss: 270.7552 - val_my_metric_fn: 0.0243
# Epoch 13/20
# 410/410 [==============================] - 1s 3ms/step - loss: 138.0382 - my_metric_fn: 0.0189 - val_loss: 270.6943 - val_my_metric_fn: 0.0247
# Epoch 14/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9907 - my_metric_fn: 0.0192 - val_loss: 270.6393 - val_my_metric_fn: 0.0251
# Epoch 15/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9480 - my_metric_fn: 0.0195 - val_loss: 270.5892 - val_my_metric_fn: 0.0254
# Epoch 16/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.9092 - my_metric_fn: 0.0198 - val_loss: 270.5439 - val_my_metric_fn: 0.0257
# Epoch 17/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8743 - my_metric_fn: 0.0200 - val_loss: 270.5026 - val_my_metric_fn: 0.0260
# Epoch 18/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8426 - my_metric_fn: 0.0203 - val_loss: 270.4649 - val_my_metric_fn: 0.0262
# Epoch 19/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8121 - my_metric_fn: 0.0205 - val_loss: 270.4181 - val_my_metric_fn: 0.0265
# Epoch 20/20
# 410/410 [==============================] - 1s 3ms/step - loss: 137.7793 - my_metric_fn: 0.0207 - val_loss: 270.3793 - val_my_metric_fn: 0.0267
# Epoch 1/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 2.2644 - my_metric_fn: -225.7933 - val_loss: 0.1648 - val_my_metric_fn: -15.2512
# Epoch 2/50
# 2761/2761 [==============================] - 7s 2ms/step - loss: 0.0408 - my_metric_fn: -3.1091 - val_loss: 0.0329 - val_my_metric_fn: -1.8169
# Epoch 3/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0146 - my_metric_fn: -0.2622 - val_loss: 0.0174 - val_my_metric_fn: -0.2795
# Epoch 4/50
# 2761/2761 [==============================] - 9s 3ms/step - loss: 0.0124 - my_metric_fn: -0.0215 - val_loss: 0.0160 - val_my_metric_fn: -0.1369
# Epoch 5/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0122 - my_metric_fn: -0.0034 - val_loss: 0.0155 - val_my_metric_fn: -0.0880
# Epoch 6/50
# 2761/2761 [==============================] - 7s 2ms/step - loss: 0.0121 - my_metric_fn: 0.0038 - val_loss: 0.0150 - val_my_metric_fn: -0.0444
# Epoch 7/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0077 - val_loss: 0.0148 - val_my_metric_fn: -0.0241
# Epoch 8/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0120 - my_metric_fn: 0.0113 - val_loss: 0.0147 - val_my_metric_fn: -0.0128
# Epoch 9/50
# 2761/2761 [==============================] - 8s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0137 - val_loss: 0.0146 - val_my_metric_fn: -0.0052
# Epoch 10/50
# 2761/2761 [==============================] - 7s 3ms/step - loss: 0.0119 - my_metric_fn: 0.0167 - val_loss: 0.0147 - val_my_metric_fn: -0.0096
# 2813/2813 [==============================] - 5s 2ms/step - loss: 0.0176 - my_metric_fn: -0.1569
# [0.017605409026145935, -0.15692119300365448]
# 2813/2813 [==============================] - 6s 2ms/step
#
# -0.5260050936248688

# %%
# Print out Predictive R^2
y_predict = yhat_df.mean(axis=1).values.reshape(-1)
y_real = merged_test_y

a = np.mean(np.square(y_predict -  y_real))
b = np.mean(np.square(y_real))
print(1-a/b)
# Out:
# -0.5260050936248688
